# %%
import seaborn as sns

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install numpy

# %%
pip install matplotlib.
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'matplotlib.': Expected end or semicolon (after name and no valid version specifier)
#     matplotlib.
#               ^

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales=pd.read_excel("C:/Users/Admin/Desktop/Big saless.xlsx")

# %%
sales
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2011-103800 2013-01-03 2013-01-07  Standard Class
# 1          2  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 2          3  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 3          4  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 4          5  CA-2011-141817 2013-01-05 2013-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9990    9991  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9991    9992  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9992    9993  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9993    9994  CA-2014-156720 2016-12-30 2017-01-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 0       DP-13000      Darren Powers     Consumer  United States
# ...

# %%
sales.shape
# Out:
# (9994, 22)

# %%
sales.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2015-05-01 00:07:12.259355648
# min       1.000000            2013-01-03 00:00:00
# 25%    2499.250000            2014-05-23 00:00:00
# 50%    4997.500000            2015-06-27 00:00:00
# 75%    7495.750000            2016-05-14 00:00:00
# max    9994.000000            2016-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2015-05-04 23:06:58.571142656  55190.379428    229.858001     3.789574
# min              2013-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2014-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2015-06-30 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
sales.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2011-103800 2013-01-03 2013-01-07  Standard Class    DP-13000
# 1       2  CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 2       3  CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 3       4  CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 4       5  CA-2011-141817 2013-01-05 2013-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment        Country          City  ...   Region  \
# 0  Darren Powers     Consumer  United States       Houston  ...  Central
# 1  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 2  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 3  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 4     Mick Brown     Consumer  United States  Philadelphia  ...     East
#
#         Product ID         Category Sub-Category  \
# ...

# %%
sales.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9990    9991  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9991    9992  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9992    9993  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9993    9994  CA-2014-156720 2016-12-30 2017-01-03  Standard Class
#
#      Customer ID      Customer Name    Segment        Country           City  \
# 9989    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 9990    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 9991    EB-13975         Erica Bern  Corporate  United States      Fairfield
# 9992    EB-13975         Erica Bern  Corporate  United States      Fairfield
# 9993    JM-15580      Jill Matthias   Consumer  United States       Loveland
#
#       ... Region       Product ID         Category Sub-Category  \
# ...

# %%
#check null value
pd.isnull(sales)
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Region  Product ID  \
# ...

# %%
sales.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2011-103800 2013-01-03 2013-01-07  Standard Class
# 1          2  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 2          3  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 3          4  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 4          5  CA-2011-141817 2013-01-05 2013-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9990    9991  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9991    9992  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9992    9993  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9993    9994  CA-2014-156720 2016-12-30 2017-01-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# ...

# %% [markdown]
# EDA(exploratory data analysis)

# %% [markdown]
# age

# %%
sales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Payment Mode'],
#       dtype='object')

# %%
X=sales.groupby(['Region']).agg({'Profit':sum}).round()
sns.barplot(x = 'Region',y= 'Profit' ,data = X,color="r")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10576\1318366171.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   X=sales.groupby(['Region']).agg({'Profit':sum}).round()
# <Axes: xlabel='Region', ylabel='Profit'>

# %% [markdown]
# age

# %%
sales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Payment Mode'],
#       dtype='object')

# %% [markdown]
# totalamountvs age group

# %%
ship_sales=sales.groupby(['Ship Mode']).agg({'Profit':'sum'})
sns.barplot(x='Ship Mode',y='Profit',color="g",data=ship_sales)
# Out:
# <Axes: xlabel='Ship Mode', ylabel='Profit'>

# %%
sales
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2011-103800 2013-01-03 2013-01-07  Standard Class
# 1          2  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 2          3  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 3          4  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 4          5  CA-2011-141817 2013-01-05 2013-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9990    9991  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9991    9992  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9992    9993  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9993    9994  CA-2014-156720 2016-12-30 2017-01-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 0       DP-13000      Darren Powers     Consumer  United States
# ...

# %% [markdown]
# sales by top 10 customers

# %%
cust=sales.groupby(['Segment']).agg({'Profit':'sum'})
sns.barplot(x='Segment',data=cust,color="b",edgecolor="b",y='Profit')
# Out:
# <Axes: xlabel='Segment', ylabel='Profit'>

# %%
cust=sales.groupby(['Order ID']).agg({'Profit':'sum'}).head(3)
sns.barplot(x='Order ID',data=cust,color="y",edgecolor="g",y='Profit')
# Out:
# <Axes: xlabel='Order ID', ylabel='Profit'>

# %%
sales
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2011-103800 2013-01-03 2013-01-07  Standard Class
# 1          2  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 2          3  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 3          4  CA-2011-112326 2013-01-04 2013-01-08  Standard Class
# 4          5  CA-2011-141817 2013-01-05 2013-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9990    9991  CA-2014-143259 2016-12-30 2017-01-03  Standard Class
# 9991    9992  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9992    9993  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 9993    9994  CA-2014-156720 2016-12-30 2017-01-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 0       DP-13000      Darren Powers     Consumer  United States
# ...

# %%
shipmode=sales[['Ship Mode','Sales']].groupby('Ship Mode').mean().round(1)
shipmode
# Out:
#                 Sales
# Ship Mode
# First Class     228.5
# Same Day        236.4
# Second Class    236.1
# Standard Class  227.6

# %%
shipmode=sales[['Ship Mode','Profit']].groupby('Ship Mode').mean().round(1)
sns.barplot(x='Ship Mode',y='Profit',color="r",linestyle=":",width=0.5,data=ship_sales,edgecolor="y",alpha=0.5)
# Out:
# <Axes: xlabel='Ship Mode', ylabel='Profit'>

# %%
sales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Payment Mode'],
#       dtype='object')

# %%
all=sales.groupby(['Customer Name','Sub-Category','Country']).agg({'Profit':"sum"}).round(1).loc['Phillina Ober','Storage','United States']         
all
# Out:
# Profit   -64.8
# Name: (Phillina Ober, Storage, United States), dtype: float64

# %%
id=sales[['City','Profit']].groupby('City').mean().round(1).head(5)
sns.barplot(x='City',y='Profit',color="y",linestyle=":",width=1,data=id,edgecolor="g",alpha=1)
# Out:
# <Axes: xlabel='City', ylabel='Profit'>
